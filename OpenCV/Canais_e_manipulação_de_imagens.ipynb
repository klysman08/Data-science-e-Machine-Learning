# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
from matplotlib import pyplot as plt

# %%
img = cv2.imread("klysman.jpg")
cv2_imshow(imgh)
# Out:
# <PIL.Image.Image image mode=RGB size=300x374 at 0x7FE0DB4C0E10>

# %%
from scipy import ndimage
img2 = ndimage.gaussian_filter(img, sigma= 5.11)
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=300x374 at 0x7FE0DC1AC198>

# %%
img2 = cv2.flip(img2, 0)
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=300x374 at 0x7FE0DC1AAEB8>

# %%
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2RGBA)
cv2_imshow(hsv)
hsv.shape
# Out:
# <PIL.Image.Image image mode=RGBA size=300x374 at 0x7FE0DBFE74E0>
# (374, 300, 4)

# %%
img = cv2.imread('Salvando.jpg',0)
hist = cv2.calcHist([img],[0],None,[256],[0,256])
plt.hist(img.ravel(),256,[0,256]); plt.show()

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=300x374 at 0x7FE0DC158438>

# %%
g = img.copy()
g[: , : , 1] = 0

cv2_imshow(g)
g.shape
# Out:
# <PIL.Image.Image image mode=RGB size=300x374 at 0x7FE0DC106DA0>
# (374, 300, 3)

# %%
b = img.copy()
b[:, :, 0] = 0
cv2_imshow(b)

for i, col in enumerate(color):
  histr = cv2.calcHist([b],[i], None, [256], [0,256])
  plt.plot(histr, color = col)
  plt.xlim([0,256])
plt.show()
# Out:
# <PIL.Image.Image image mode=RGB size=300x374 at 0x7FE0DB420438>

# %%
r = img.copy()
r[:, :, 2] = 0
cv2_imshow(r)
# Out:
# <PIL.Image.Image image mode=RGB size=300x374 at 0x7FE0DC158358>

# %%
cv2.imwrite('Salvando.jpg', r)

# %%
b_channel, g_channel, r_channel = cv2.split(img)
img_BRG = cv2.merge(b_channel, g_channel)

# %%
cv2_imshow(img_BRG)
img_BRG.shape
