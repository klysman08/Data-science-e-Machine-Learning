# %%
from keras.datasets import mnist
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten
from keras.utils import np_utils
from keras.models import Sequential

# %%
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()

# %%
#Convertendo as imagens em um array de 3 dimnesões

X_train = X_train.reshape(X_train.shape[0], 28, 28, 1)
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1)

#Normalizando os dados

X_train = X_train / 255
X_test = X_test / 255

Y_train = np_utils.to_categorical(Y_train) #Convertendo as labels 1 2 3...9 para um vetor para ser computado na rede

# %%
#Criando o modelo

model = Sequential()
model.add(Conv2D(32, (3,3), activation='relu', input_shape=(28,28,1)))
model.add(MaxPooling2D(pool_size=(1,1)))
model.add(Flatten())
model.add(Dense(Y_train.shape[1], activation='softmax'))

model.summary()

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['acc'])
model.fit(X_train, Y_train, epochs=2, batch_size=32)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 26, 26, 32)        0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 21632)             0
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                216330
# =================================================================
# Total params: 216,650
# Trainable params: 216,650
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/2
# 60000/60000 [==============================] - 47s 780us/step - loss: 0.1919 - acc: 0.9437
# Epoch 2/2
# 60000/60000 [==============================] - 47s 781us/step - loss: 0.0712 - acc: 0.9790

# %%
(model.predict(X_test[1:]))
# Out:
# array([[1.25784641e-06, 1.48989056e-05, 9.99757469e-01, ...,
#         1.60163613e-14, 1.05263723e-06, 3.80208495e-12],
#        [1.12210197e-04, 9.91006434e-01, 2.18281033e-03, ...,
#         7.49540457e-04, 7.03869271e-04, 1.55807957e-05],
#        [9.99742806e-01, 2.45761402e-08, 3.09099159e-05, ...,
#         8.58525709e-06, 2.03560901e-07, 6.65593461e-06],
#        ...,
#        [2.12335749e-08, 1.32486084e-08, 4.28736158e-08, ...,
#         2.14171421e-04, 1.78100327e-05, 1.69623853e-03],
#        [4.20229526e-07, 2.53058889e-08, 5.84978892e-08, ...,
#         2.25329202e-07, 8.13544670e-04, 4.95854010e-07],
#        [1.87304217e-09, 2.61769079e-12, 6.39762050e-07, ...,
#         6.53881185e-11, 1.41962098e-09, 1.24942365e-11]], dtype=float32)
