# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import numpy as np
import pandas as pd

# %%
train = pd.read_csv('drive/My Drive/Machine Learning/Previsão de inventário/train.csv', index_col='sku').fillna(-1)
test = pd.read_csv('drive/My Drive/Machine Learning/Previsão de inventário/test.csv', index_col='sku').fillna(-1)

# %%
X_train, y_train = train.drop('isBackorder', axis=1), train['isBackorder']

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=5)
pca.fit(X_train.values)  
print(pca.explained_variance_ratio_)  
print(pca.singular_values_)

# %%
X_train_pca = pd.DataFrame(pca.transform(X_train))

# %%
pip install git+git://github.com/keras-team/autokeras@master#egg=autokeras # for 1.0 version
# Out:
# Collecting autokeras
#   Cloning git://github.com/keras-team/autokeras (to revision master) to /tmp/pip-install-_0x0h57_/autokeras
#   Running command git clone -q git://github.com/keras-team/autokeras /tmp/pip-install-_0x0h57_/autokeras
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.6/dist-packages (from autokeras) (1.15.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from autokeras) (0.21.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from autokeras) (1.17.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from autokeras) (0.25.3)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.6/dist-packages (from autokeras) (2.2.3)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow->autokeras) (0.8.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow->autokeras) (1.12.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow->autokeras) (0.8.0)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow->autokeras) (1.0.8)
# Requirement already satisfied: tensorboard<1.16.0,>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow->autokeras) (1.15.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow->autokeras) (3.1.0)
# Requirement already satisfied: tensorflow-estimator==1.15.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow->autokeras) (1.15.1)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow->autokeras) (1.11.2)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow->autokeras) (1.15.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow->autokeras) (1.1.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow->autokeras) (1.1.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow->autokeras) (0.33.6)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow->autokeras) (0.1.8)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow->autokeras) (3.10.0)
# Requirement already satisfied: gast==0.2.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow->autokeras) (0.2.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->autokeras) (0.14.0)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->autokeras) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas->autokeras) (2.6.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->autokeras) (2018.9)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow->autokeras) (2.8.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow->autokeras) (41.6.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow->autokeras) (0.16.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow->autokeras) (3.1.1)
# Building wheels for collected packages: autokeras
#   Building wheel for autokeras (setup.py) ... done
#   Created wheel for autokeras: filename=autokeras-1.0.0a0-cp36-none-any.whl size=47518 sha256=3a061dd376f761b4b52fcac11c9cd4011a0aa1d95e72ec8ecfa243169ee5275b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-qcxgqi25/wheels/55/b0/bc/7304f4fcafa1a7f163e4e4da7cb951f17b1cacf2e76b7d3146
# Successfully built autokeras
# Installing collected packages: autokeras
# Successfully installed autokeras-1.0.0a0

# %%
pip install kerastuner
# Out:
# ERROR: Could not find a version that satisfies the requirement kerastuner (from versions: none)
# ERROR: No matching distribution found for kerastuner

# %%
import autokeras as ak

clf = ak.ImageClassifier()
clf.fit(x_train, y_train)
results = clf.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-4fd4413739ff> in <module>()
# ----> 1 import autokeras as ak
#       2
#       3 clf = ak.ImageClassifier()
#       4 clf.fit(x_train, y_train)
#       5 results = clf.predict(x_test)
#
# /usr/local/lib/python3.6/dist-packages/autokeras/__init__.py in <module>()
# ----> 1 from autokeras.auto_model import AutoModel
#       2 from autokeras.auto_model import GraphAutoModel
#       3 from autokeras.const import Constant
#       4 from autokeras.hypermodel.block import ConvBlock
#       5 from autokeras.hypermodel.block import DenseBlock
#
# /usr/local/lib/python3.6/dist-packages/autokeras/auto_model.py in <module>()
# ----> 1 import kerastuner
#       2 import tensorflow as tf
#       3 from tensorflow.python.util import nest
#       4
#       5 from autokeras import meta_model
#
# ModuleNotFoundError: No module named 'kerastuner'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import autokeras as ak
from keras.datasets import mnist

# Prepare the data.
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.reshape(x_train.shape + (1,))
x_test = x_test.reshape(x_test.shape + (1,))

# Search and train the classifier.
clf = ak.ImageClassifier(max_trials=100)
clf.fit(x_train, y_train)
y = clf.predict(x_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-7df6fa35af3d> in <module>()
# ----> 1 import autokeras as ak
#       2 from keras.datasets import mnist
#       3
#       4 # Prepare the data.
#       5 (x_train, y_train), (x_test, y_test) = mnist.load_data()
#
# /usr/local/lib/python3.6/dist-packages/autokeras/__init__.py in <module>()
# ----> 1 from autokeras.auto_model import AutoModel
#       2 from autokeras.auto_model import GraphAutoModel
#       3 from autokeras.const import Constant
#       4 from autokeras.hypermodel.block import ConvBlock
#       5 from autokeras.hypermodel.block import DenseBlock
#
# /usr/local/lib/python3.6/dist-packages/autokeras/auto_model.py in <module>()
# ----> 1 import kerastuner
#       2 import tensorflow as tf
#       3 from tensorflow.python.util import nest
#       4
#       5 from autokeras import meta_model
#
# ModuleNotFoundError: No module named 'kerastuner'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
