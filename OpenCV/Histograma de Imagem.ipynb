# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from google.colab.patches import cv2_imshow

# %% [markdown]
# Carregando imagem

# %%
img = cv2.imread("klysman.jpg", 0)

# %% [markdown]
# Histograma

# %%
plt.hist(img.ravel(), 256, [0,256])
plt.show()
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=300x374 at 0x7FD7093A4748>

# %% [markdown]
# Histograma colorido

# %%
img = cv2.imread("klysman.jpg")
color = ('b', 'g', 'r')

# %%
for i, col in enumerate(color):
  histr = cv2.calcHist([img],[i], None, [256], [0,256])
  plt.plot(histr, color = col)
  plt.xlim([0,256])
cv2_imshow(img)
plt.show()
# Out:
# <PIL.Image.Image image mode=RGB size=300x374 at 0x7FD70901EB38>
